# %%
import numpy as np
from numpy import asarray
from PIL import Image
from pylab import *

# load the image
image = Image.open('Images/test.jpeg').convert('L')

# convert image to numpy array
image_array = asarray(image)

# plot the image
imshow(image_array)

# summarize shape
print(image_array.shape)
# Out:
# (2325, 2325)

# %%
# %matplotlib

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

# draw sphere
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color="r")
# Out:
# Using matplotlib backend: Qt5Agg

# %%
from PIL import Image
import ipyvolume as ipv
import numpy as np
import matplotlib.pyplot as plt

# Get original image
size_image = Image.open('Images/1.jpeg', 'r')

# Original image size
print(size_image.size)

# Create a 3D array of size of image by 11
stack = np.ndarray(shape=(size_image.size[0], size_image.size[1], 100)) #empty array

source = Image.open('Images/1' + ".jpeg", 'r').convert('L') #open image convertiung it to grayscale

source.show() #show grayscale image
m = np.asarray(source) #convert image to array
#     print(m) #print array 
# print(m.shape) #print array shape

for s in range(99):
    stack[:, :, s] = m #fill empty array with image
    
print(stack)
print(stack.shape) #print array shape

# stack = stack.nonzero() #gets >100 values from stacked
ipv.figure()
ipv.volshow(stack,tf=None)
ipv.show()
# Out:
# (2325, 2325)
# [[[106. 106. 106. ... 106. 106.   0.]
#   [106. 106. 106. ... 106. 106.   0.]
#   [106. 106. 106. ... 106. 106.   0.]
#   ...
#   [108. 108. 108. ... 108. 108.   0.]
#   [108. 108. 108. ... 108. 108.   0.]
#   [108. 108. 108. ... 108. 108.   0.]]
#
#  [[106. 106. 106. ... 106. 106.   0.]
#   [106. 106. 106. ... 106. 106.   0.]
#   [106. 106. 106. ... 106. 106.   0.]
#   ...
#   [108. 108. 108. ... 108. 108.   0.]
#   [108. 108. 108. ... 108. 108.   0.]
#   [108. 108. 108. ... 108. 108.   0.]]
#
#  [[106. 106. 106. ... 106. 106.   0.]
#   [106. 106. 106. ... 106. 106.   0.]
#   [106. 106. 106. ... 106. 106.   0.]
#   ...
#   [108. 108. 108. ... 108. 108.   0.]
#   [108. 108. 108. ... 108. 108.   0.]
#   [108. 108. 108. ... 108. 108.   0.]]
#
#  ...
#
#  [[109. 109. 109. ... 109. 109.   0.]
#   [109. 109. 109. ... 109. 109.   0.]
#   [109. 109. 109. ... 109. 109.   0.]
#   ...
#   [113. 113. 113. ... 113. 113.   0.]
#   [113. 113. 113. ... 113. 113.   0.]
# ...

# %%
ipv.pylab.save("Model.html", makedirs=True, title='IPyVolume Widget', all_states=False, offline=False, scripts_path='js', drop_defaults=False, template_options=(('extra_script_head', ''), ('body_pre', ''), ('body_post', '')), devmode=False, offline_cors=False)

# %%
import ipywidgets as widgets
import numpy as np
import ipyvolume as ipv

# a scatter plot
x, y, z = np.random.normal(size=(3, 100))



fig = ipv.figure()
scatter = ipv.scatter(x, y, z, marker='box')
scatter.connected = True  # draw connecting lines
ipv.show()
